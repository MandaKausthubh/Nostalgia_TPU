# %%
# !wandb login
# Out:
# wandb: WARNING Using legacy-service, which is deprecated. If this is unintentional, you can fix it by ensuring you do not call `wandb.require('legacy-service')` and do not set the WANDB_X_REQUIRE_LEGACY_SERVICE environment variable.
# wandb: Currently logged in as: kausthubh-manda (kausthubh-manda-international-institute-of-information-t) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import os
import wandb
import random
import pandas

# %%
import wandb

wandb.login()
api = wandb.Api()

viewer = api.viewer
print("Logged in as:", viewer.username)
# Out:
# wandb: Currently logged in as: kausthubh-manda (kausthubh-manda-international-institute-of-information-t) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Logged in as: kausthubh-manda

# %%
import wandb
api = wandb.Api()

# run is specified by <entity>/<project>/<run_id>
run = api.run("manda-kausthubh-international-institute-of-information-t/Nostalgia/3cwvj375")

# save the metrics for the run to a csv file
metrics_dataframe = run.history()
metrics_dataframe.to_csv("metrics.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/normalize.py:29, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      28 try:
# ---> 29     return func(*args, **kwargs)
#      31 except requests.HTTPError as error:
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/api.py:1278, in Api.run(self, path)
#    1276 if not self._runs.get(path):
#    1277     # Individual runs should load full data by default
# -> 1278     self._runs[path] = public.Run(
#    1279         self.client,
#    1280         entity,
#    1281         project,
#    1282         run_id,
#    1283         lazy=False,
#    1284         service_api=self._service_api,
#    1285     )
#    1286 return self._runs[path]
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/runs.py:676, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps, lazy, service_api)
#     674 self._service_api = service_api
# --> 676 self.load(force=not _attrs)
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/runs.py:909, in Run.load(self, force)
#     908 else:
# --> 909     return self._load_with_fragment(RUN_FRAGMENT, RUN_FRAGMENT_NAME, force)
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/runs.py:804, in Run._load_with_fragment(self, fragment, fragment_name, force)
#     799 if (
#     800     response is None
#     801     or response.get("project") is None
#     802     or response["project"].get("run") is None
#     803 ):
# --> 804     raise ValueError("Could not find run {}".format(self))
#     805 self._attrs = response["project"]["run"]
#
# ValueError: Could not find run <Run manda-kausthubh-international-institute-of-information-t/Nostalgia/3cwvj375 (None)>
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 api = wandb.Api()
#       4 # run is specified by <entity>/<project>/<run_id>
# ----> 5 run = api.run("manda-kausthubh-international-institute-of-information-t/Nostalgia/3cwvj375")
#       7 # save the metrics for the run to a csv file
#       8 metrics_dataframe = run.history()
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/normalize.py:83, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      81     raise
#      82 else:
# ---> 83     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/normalize.py:29, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      27 message = "Whoa, you found a bug."
#      28 try:
# ---> 29     return func(*args, **kwargs)
#      31 except requests.HTTPError as error:
#      32     errors = parse_backend_error_messages(error.response)
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/api.py:1278, in Api.run(self, path)
#    1275 entity, project, run_id = self._parse_path(path)
#    1276 if not self._runs.get(path):
#    1277     # Individual runs should load full data by default
# -> 1278     self._runs[path] = public.Run(
#    1279         self.client,
#    1280         entity,
#    1281         project,
#    1282         run_id,
#    1283         lazy=False,
#    1284         service_api=self._service_api,
#    1285     )
#    1286 return self._runs[path]
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/runs.py:676, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps, lazy, service_api)
#     673 self._is_loaded: bool = False
#     674 self._service_api = service_api
# --> 676 self.load(force=not _attrs)
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/runs.py:909, in Run.load(self, force)
#     905     return self._load_with_fragment(
#     906         LIGHTWEIGHT_RUN_FRAGMENT, LIGHTWEIGHT_RUN_FRAGMENT_NAME, force
#     907     )
#     908 else:
# --> 909     return self._load_with_fragment(RUN_FRAGMENT, RUN_FRAGMENT_NAME, force)
#
# File ~/miniconda3/envs/nostalgia/lib/python3.10/site-packages/wandb/apis/public/runs.py:804, in Run._load_with_fragment(self, fragment, fragment_name, force)
#     798 response = self._exec(query)
#     799 if (
#     800     response is None
#     801     or response.get("project") is None
#     802     or response["project"].get("run") is None
#     803 ):
# --> 804     raise ValueError("Could not find run {}".format(self))
#     805 self._attrs = response["project"]["run"]
#     807 self._state = self._attrs["state"]
#
# CommError: Could not find run <Run manda-kausthubh-international-institute-of-information-t/Nostalgia/3cwvj375 (None)>
